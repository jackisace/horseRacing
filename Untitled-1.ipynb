# %%
# Fixed dependencies - do not remove or change.
import pytest
import pandas as pd
import numpy as np
import datetime

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.impute import SimpleImputer
import pickle
from structure import horse
import structure
import os
import random

import pandas as pd

#import matplotlib.pyplot as plt
import tensorflow as tf


#print("loading data")
#raw_data = pd.read_excel("hr.xlsx")
#print("data loaded")
#
#print("loading data")
#raw_predict_data = pd.read_excel("hr_predict.xlsx")
#print("data loaded")

# %%
# SAVE ALL RACES

files = os.listdir("pickles/")
races = []


def loadAll():
    global races
    global files
    for file in files:
        filename =  "pickles/{}".format(file)
        try:
            with open(filename, "rb") as f:
                thisRace = pickle.load(f)
                races.append(thisRace)
        except:
            pass

loadAll()

for race in races:
    race.save()

# %%
raceFilename = "pickles/822184.pickle"
thisRace = None
with open(raceFilename, "rb") as f:
    thisRace = pickle.load(f)

thisRace.print()
# Out:
# https://www.racingpost.com/racecards/190/listowel/2022-09-23/822184
# - - - - - - - -
# Horse                    Jockey                   Trainer                  Age       TS        Weight    Rating    Price     Country   PosL
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/1480283852.py in <module>
#       4     thisRace = pickle.load(f)
#       5
# ----> 6 thisRace.print()
#
# c:\Users\JackT\horseRacing\structure.py in print(self)
#     265                                                                                     "PosL"))
#     266         for horse in self.horses:
# --> 267             horse.print()
#     268
#     269
#
# c:\Users\JackT\horseRacing\structure.py in print(self)
#     532
#     533     def print(self):
# --> 534         print("{:25s}{:25s}{:25s}{:10s}{:10s}{:10s}{:10s}{:10s}{:10s}{:10s}".format(self.name,
#     535                                                                                     self.jockey,
#     536                                                                                     self.trainer,
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
files = os.listdir("pickles/")
races = []


def loadAll():
    global races
    for file in files:
        filename =  "pickles/{}".format(file)
        try:
            with open(filename, "rb") as f:
                thisRace = pickle.load(f)
                races.append(thisRace)
        except:
            pass

def horseCount():
    horseCount = 0
    for race in races:
        horseCount += len(race.horses)
    print(horseCount, "horses")

def getRace(raceId):
    global files
    for file in files:
        
        if str(raceId) in file:
            filename =  "pickles/{}".format(file)
            with open(filename, "rb") as f:
                thisRace = pickle.load(f)
                return thisRace
            
tomorrow = "23 Sep 2022"
loadAll()
data = []
for race in races:
    if race.date != tomorrow:
        d = race.getData()
        for line in d:
            data.append(line)
tomorrowsLength = len(data)
print(tomorrowsLength)
for race in races:
    if race.date == tomorrow:
        d = race.getData()
        for line in d:
            data.append(line)
print(len(data))

raw_data = pd.DataFrame(data)
originalData = data[tomorrowsLength:]
raw_data.to_csv("final.csv")

# %%
races[-1].print()
# Out:
# https://www.racingpost.com/results/393/lingfield-aw/2022-04-06/806521
# 6 Apr 2022 145 Lingfield (AW) Watch Racing Free Online At Coral Handicap (Class 6) (0-65, 3yo) 6f Standard
# Horse                    Jockey                   Trainer                  Age       TS        Weight    Rating    Price     Country   PosL
# Man On A Mission         Luke Morris              Peter Charalambous       3         47        8-9       53        12.0      ENG
# Judy's Park              James Doyle              George Boughey           3         58        9-7p      65        1.625     ENG       hd
# Bang On The Bell         Tom Marquand             J R Jenkins              3         48        9-5b      63        3.0       ENG       2[2¼]
# Brazen Idol              Joey Haynes              Simon Pearce             3         30        8-21      46        9.0       ENG       nk[2½]
# Jaas Yard                Harry Burns              John Butler              3         31        8-6h      55        12.0      IRE       2[4½]
# Vintage Fashion          Silvestre De Sousa       Charlie & Mark Johnston  3         19        8-10      54        3.5       IRE       2¾[7¼]

# %%
raw_data = pd.DataFrame(data)

columnsToEncode = [1, 4, 5, 6, 7, 8, 9, 10, 11, 16, 18, 19, 20, 21, 22]
le = LabelEncoder()
for column in columnsToEncode:
    first_col = raw_data.pop(column)
    first_col = le.fit_transform(first_col)
    raw_data.insert(0, column,first_col)




x = raw_data.iloc[:, :-1].values
y = raw_data.iloc[:, -1:].values

for i in range(len(y)):
    if y[i] < 2:
        y[i] = 1.0
    else:
        y[i] = 0.0

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(x)
x = imputer.transform(x)



#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = todaysLength)
#originalXTest = x_test

#todaysLength

sc = StandardScaler()
#x_train = sc.fit_transform(x_train)
#x_test = sc.transform(x_test)

x = sc.fit_transform(x)
x_train = x[:todaysLength]
x_pred = x[todaysLength:]

y_train = y[:todaysLength]
y_pred = y[todaysLength:]



ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units=18, activation="relu"))
ann.add(tf.keras.layers.Dense(units=18, activation="relu"))
ann.add(tf.keras.layers.Dense(units=18, activation="relu"))
ann.add(tf.keras.layers.Dense(units=18, activation="relu"))
ann.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
ann.fit(x_train, y_train, batch_size = 32, epochs = 10)
# Out:
# Epoch 1/10
# 9576/9576 [==============================] - 29s 3ms/step - loss: 0.1810 - accuracy: 0.9176
# Epoch 2/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.1518 - accuracy: 0.9299
# Epoch 3/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.1257 - accuracy: 0.9419
# Epoch 4/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.1041 - accuracy: 0.9531
# Epoch 5/10
# 9576/9576 [==============================] - 27s 3ms/step - loss: 0.0847 - accuracy: 0.9631
# Epoch 6/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.0794 - accuracy: 0.9654
# Epoch 7/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.0771 - accuracy: 0.9665
# Epoch 8/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.0747 - accuracy: 0.9677
# Epoch 9/10
# 9576/9576 [==============================] - 25s 3ms/step - loss: 0.0732 - accuracy: 0.9685
# Epoch 10/10
# 9576/9576 [==============================] - 26s 3ms/step - loss: 0.0717 - accuracy: 0.9690

# %%
results = ann.predict(x_pred)
for i in range(len(results)):
    print(originalData[i][9], results[i], y_pred[i])
# Out:
# 15/15 [==============================] - 0s 2ms/step
# Installation [0.7225446] [1]
# Queenie Rooney [1.302036e-19] [0]
# Concert Boy [0.] [0]
# Colnago [0.00544176] [0]
# Erazmus [0.] [0]
# Smooth Red [0.01385363] [0]
# Highland Penny [0.00330614] [1]
# Shannon Gray [0.] [0]
# Good Bye Milan [0.] [0]
# Royal Eagle [0.] [0]
# Must Be Dreaming [3.8852974e-07] [0]
# Aprils Joy [0.] [0]
# What An Ocean [0.] [0]
# Frontline Worker [0.] [0]
# Killoughteen [0.] [0]
# Sean Says [0.] [0]
# Monnie Shanahan [0.] [0]
# Female Approach [0.] [0]
# Mullaghmore Wave [9.95104e-05] [0]
# Robyndeglory [6.579769e-36] [0]
# Lonesome Day [0.] [0]
# Ellens Angel [0.] [0]
# Wicklow Flyer [0.] [0]
# Greenhill Damsel [0.] [0]
# Run For Pat [0.00116227] [1]
# Battle Of Mirbat [0.] [0]
# Saint Bernadette [0.00445088] [0]
# Who's Houdini [0.] [0]
# Sir Daniel [0.] [0]
# Ned The Smith [8.99186e-05] [0]
# Twolittlegirls [1.09144685e-05] [0]
# Glenstan [0.] [0]
# What Path [0.24031444] [0]
# Wee Birl [0.00619623] [0]
# Chemical Energy [0.33057883] [1]
# Mattie's Mountain [0.] [0]
# Whosgotyanow [0.] [0]
# Barnacullia [0.] [0]
# Ferdia [0.] [0]
# Cornerkova [0.] [0]
# Easy Game [0.0014438] [1]
# Kemboy [0.] [0]
# The Little Yank [0.00028063] [0]
# Call Me Lyreen [0.19791777] [0]
# Polo Lounge [0.00239512] [1]
# One For Lucy [0.] [0]
# Master Player [5.6431204e-06] [0]
# Cillians Charm [0.] [0]
# Watergrangedreamer [0.] [0]
# Val The Man [0.00113605] [0]
# Rebel Pat [0.] [0]
# Knockwilliambridge [0.] [0]
# Bright Lad [0.] [0]
# Badgerisland [0.] [0]
# Ozark Thunder [0.] [0]
# Velvet Reel [0.] [0]
# Native Cloud [0.] [0]
# Mordred [0.6908014] [1]
# Lusaka [0.] [0]
# Indigo Lake [0.] [0]
# Special Buddy [0.6865707] [1]
# Agent Saonois [0.] [0]
# Easkey Lad [0.] [0]
# Heronord [0.] [0]
# Right Destination [1.2019672e-06] [0]
# Arbennig [0.00280525] [0]
# Mr Freedom [0.28162032] [1]
# Executive Pool [0.] [0]
# Borntobealeader [0.] [0]
# I Have A Voice [0.00150361] [0]
# Starspangledjama [0.00782169] [0]
# Boudica Warrior [0.02056907] [0]
# See The Sea [0.8913501] [1]
# Glimpse Of Gold [0.] [0]
# Thibault [0.] [0]
# Sergeant [4.487276e-05] [0]
# Just The Man [0.] [0]
# Ray's The One [0.] [0]
# Runrized [0.] [0]
# Only Money [7.2832525e-05] [1]
# Barest Of Margins [5.876109e-34] [0]
# Trumps Benefit [0.00278451] [0]
# Fairway Freddy [5.5608114e-05] [0]
# Iris Dancer [0.9459765] [1]
# Kentucky Rose [0.] [0]
# Miss Bella Brand [0.] [0]
# Pearl Of Qatar [0.] [0]
# Roshambo [1.7284874e-08] [0]
# Guest List [3.5107664e-08] [0]
# Soller Bay [0.] [0]
# Selby's Pride [2.6063844e-07] [0]
# Rose Bandit [0.0004678] [0]
# Fox Hill [1.3556917e-05] [0]
# Little Miss Dynamo [7.514997e-27] [0]
# Boomtime Banker [0.00418757] [1]
# Cherry Cola [0.] [0]
# Cadeau D'Or [0.] [0]
# Dellboy Trotter [3.2829445e-05] [0]
# Say Nothing [0.00586658] [0]
# Andapa [0.] [0]
# Texan Nomad [0.] [0]
# Pawpaw [0.] [0]
# Coillte Eile [1.3477029e-10] [0]
# Dante's View [0.] [0]
# Lake Washington [1.3104942e-06] [0]
# Invictus De Brion [0.05503497] [1]
# Alien Storm [0.] [0]
# Merrijig [0.] [0]
# Dannystory [0.] [0]
# Faith In Humanity [0.6765781] [1]
# Gina Romantica [0.83518946] [0]
# Bahamian Club [1.9370797e-05] [0]
# Majestic Glory [1.6733435e-05] [0]
# A Mo Reay [4.505885e-19] [0]
# Miss Carol Ann [0.02785805] [0]
# Golden Rocket [4.3141808e-13] [0]
# Sail By [3.777887e-18] [0]
# Breeze Easy [5.5878754e-06] [0]
# Al Zaraqaan [0.32483658] [1]
# Monsieur Vic [0.] [0]
# Ambrosius [0.] [0]
# Mr Suarez [6.2148423e-34] [0]
# Last Reference [2.576043e-23] [0]
# Roxie Rose [0.02435734] [0]
# Duca Di Como [0.7870673] [1]
# Plantstepsdream [0.] [0]
# Karibana [0.] [0]
# Ellis St Martin [0.] [0]
# Pusjkin [5.644523e-16] [0]
# Mystery Night [0.] [0]
# Beach Road One [2.895373e-23] [0]
# Manitou [0.68999195] [1]
# Got A Lot [0.] [0]
# Nuevo Estrella [2.0742898e-06] [0]
# Starlight Song [9.451575e-06] [0]
# Lovely Spirit [0.] [0]
# Diamond Soul [0.] [0]
# Brazen Soul [0.] [0]
# Approach Glory [0.] [0]
# Hard One To Please [0.8401114] [1]
# Outbox [3.371864e-11] [0]
# Master Bloom [1.0553251e-10] [0]
# Quebello [5.8740787e-16] [0]
# Merlin's Beard [0.] [0]
# Espen Hill [0.04012617] [0]
# White Heart [0.] [0]
# Seneschal [0.00207648] [0]
# Timo Nurmos [0.00134971] [0]
# Jet Action [2.625157e-16] [0]
# Panjari [1.2553325e-10] [0]
# Iron Butterfly [0.] [0]
# Auenfurst [0.] [0]
# Virginia Storm [0.] [0]
# Sublissimo [1.8912082e-20] [0]
# Could Be King [0.8000716] [1]
# Waldersee [0.] [0]
# Good Eye [0.] [0]
# Irish Action [0.00064909] [0]
# Brian Ryan [2.0728565e-07] [0]
# El Guanche [1.1214247e-25] [0]
# Tabdeed [0.] [0]
# Youonlyliveonce [0.] [0]
# City Code [4.4353406e-16] [0]
# Marshi [0.] [0]
# Art House [0.8478547] [1]
# Saliera [0.72783077] [0]
# Eglantyne [2.548678e-09] [0]
# La Ruelle [0.] [0]
# Memory Raison [0.] [0]
# Rouge Lignage [0.] [0]
# My Symphony [3.5544626e-11] [0]
# Hizuru Jo [1.8700083e-10] [0]
# Saint Camellia [0.] [0]
# Van Ruler [0.] [0]
# Personal High [0.] [0]
# Berry Venus [0.] [0]
# Brule Ton Coeur [0.] [0]
# Minamoto Faith [6.0495418e-06] [0]
# Tunnes [0.8426396] [1]
# Sir Filip [0.] [0]
# Nerium [0.] [0]
# Hipop De Loire [0.] [0]
# Normfliegerin [0.00025672] [0]
# Ability [0.] [0]
# Earlofthecotswolds [0.] [0]
# Diamantis [0.] [0]
# Nacido [1.4189884e-13] [0]
# Sir Polski [0.] [0]
# Quebueno [0.] [0]
# Gifted Ruler [0.22984038] [1]
# Zuraig [0.] [0]
# Gordonstoun [0.] [0]
# Grifter [0.] [0]
# Barneys Gift [1.4102156e-07] [0]
# California Vanes [0.8218739] [1]
# Miracles [3.4210143e-14] [0]
# Luck Star [1.3410475e-08] [0]
# Colourful Prince [0.] [0]
# Telecom Missile [9.313318e-11] [0]
# Viva A La [0.] [0]
# Win Win Charity [0.] [0]
# Dream Catcher [0.] [0]
# Winwin Thirtythree [0.5011295] [1]
# Aurora Hero [0.] [0]
# Towards Success [0.18585598] [0]
# Lotus Favorites [3.3520128e-10] [0]
# Booming Well [0.] [0]
# Zacian [3.1066197e-08] [0]
# Brave Power [8.683763e-06] [0]
# Apex Top [0.01614817] [0]
# Travel Glory [0.] [0]
# Fortune Marbo [0.00177262] [0]
# Foxhunter Way [0.] [0]
# Golden Four [0.00717801] [0]
# Leisure And Gold [0.] [0]
# Nobody Knows [0.] [0]
# Quadruple Double [0.8451783] [1]
# Lucky Ruby [0.] [0]
# Thunderstrike [0.] [0]
# Stand Up [3.0568267e-13] [0]
# Chiron [0.] [0]
# Lady First [4.560994e-10] [0]
# E Brother [0.02457616] [0]
# Happy Tango [1.6848026e-06] [0]
# Chiu Chow Brother [0.6060419] [1]
# U W Brother [0.] [0]
# Boys Party [0.] [0]
# G One Excellent [0.00292935] [0]
# El Jefe [0.] [0]
# Best For You [2.266037e-09] [0]
# Happy Gathering [2.060172e-05] [0]
# Amazing News [0.01256447] [0]
# Oh Bravo [0.09197422] [0]
# Sea Monarch [0.03536092] [0]
# All Is Ready [0.] [0]
# Felix The King [8.943089e-09] [0]
# Give Way Please [0.] [0]
# Many Wins [0.] [0]
# President's Choice [0.77267665] [1]
# Tailor Made [0.] [0]
# Chater Pins [0.00183617] [0]
# Darci Joy [1.9643304e-12] [0]
# Oscar Glory [0.] [0]
# Smiling Time [2.998702e-06] [0]
# Turquoise Alpha [7.011772e-10] [0]
# Ezra [9.6936565e-06] [0]
# Flying Mighty [0.] [0]
# Palace Pal [2.1119761e-10] [0]
# Red Elysees [0.] [0]
# Born The Same Day [0.] [0]
# Colourful Baron [0.] [0]
# Kowloon Great [0.] [0]
# Baebae Tsoi [0.6769738] [1]
# On Excel Star [0.] [0]
# Indigenous Realm [3.0464644e-14] [0]
# Kasi Farasi [0.4186968] [0]
# Hk Dragon [1.9643603e-12] [0]
# Forever Glorious [0.] [0]
# Voyage Star [0.08186897] [0]
# Lifeline Vision [5.987711e-11] [0]
# Pride Of Eight [0.0016087] [0]
# Happy Day [0.] [0]
# Win Win [1.1582795e-05] [0]
# Prosecco [0.] [0]
# Cheery [0.] [0]
# Setanta [0.74230206] [1]
# Happy Sharing [3.365528e-15] [0]
# Super Winner [1.9554478e-09] [0]
# Star Brite [2.471414e-05] [0]
# Bundle Of Charm [1.0431281e-13] [0]
# Ready To Win [0.] [0]
# California Concord [0.] [0]
# Excellent Daddy [0.] [0]
# Highly Proactive [0.] [0]
# Super Win Dragon [0.80826086] [1]
# Man Star [0.] [0]
# Czarson [0.] [0]
# Helene Wisdom Star [0.] [0]
# Mr Valiant [0.] [0]
# Kai Xin Dragon [0.] [0]
# Lucky Fun [0.] [0]
# Call Me Teddy [8.6965554e-07] [0]
# Red Desert [1.304489e-16] [0]
# Flying Bonus [0.] [0]
# Everyone's Victory [0.46971124] [0]
# Golden Warsteed [0.] [0]
# Lucky With You [0.6950218] [1]
# Handsome Bo Bo [1.960786e-06] [0]
# Run Run Cool [0.] [0]
# Whizz Kid [3.2871175e-13] [0]
# Apache Pass [0.] [0]
# Astrologer [0.] [0]
# Classic Unicorn [0.] [0]
# Atomic Force [0.] [0]
# We The South [0.] [0]
# Mr Ascendency [0.8438403] [1]
# Kasa Papa [0.] [0]
# Red Titan [7.1231085e-08] [0]
# Master Hero [4.8315378e-15] [0]
# Charity Grace [0.34579146] [0]
# Win Win Fighter [0.] [0]
# Handsome Twelve [2.3235323e-06] [0]
# Erimo [7.1601905e-11] [0]
# Royal Bomb [6.931491e-08] [0]
# Round The Earth [0.] [0]
# Dragon Fortune [2.338497e-11] [0]
# Super Ten [0.] [0]
# Ultra Express [0.] [0]
# The Gay Blade [0.72812635] [1]
# Caleta Sunrise [0.] [0]
# Bonito Cavalo [0.00086953] [0]
# Raydoun [0.] [0]
# Golden Rainbow [4.817409e-09] [0]
# Baileys Liberty [0.00225855] [0]
# Clarets Glory [0.386458] [0]
# Miss Calculation [0.8591589] [0]
# Matty Too [0.00098919] [0]
# Gentle Ellen [0.] [0]
# Wiesentau [0.6674722] [1]
# Gladys Senora [0.] [0]
# Winter Reprise [0.] [0]
# Mansour [0.] [0]
# Top Max [1.0598361e-09] [0]
# Well And Truly [0.] [0]
# Fantastic Spirit [0.] [0]
# Antelope Canyon [0.] [0]
# Ready For The Lady [0.7569894] [1]
# British Royalty [0.00011154] [0]
# Collective Force [0.15107161] [0]
# King Vega [0.] [0]
# Elusive Knight [0.] [0]
# Enchant Me [0.] [0]
# Art House [0.8478547] [1]
# Saliera [0.72783077] [0]
# Eglantyne [2.548678e-09] [0]
# La Ruelle [0.] [0]
# Memory Raison [0.] [0]
# Rouge Lignage [0.] [0]
# My Symphony [3.5544626e-11] [0]
# Hizuru Jo [1.8700083e-10] [0]
# Saint Camellia [0.] [0]
# Van Ruler [0.] [0]
# Personal High [0.] [0]
# Berry Venus [0.] [0]
# Brule Ton Coeur [0.] [0]
# Minamoto Faith [6.0495418e-06] [0]
# Wiesentau [0.6674722] [1]
# Gladys Senora [0.] [0]
# Winter Reprise [0.] [0]
# Mansour [0.] [0]
# Top Max [1.059822e-09] [0]
# Well And Truly [0.] [0]
# Fantastic Spirit [0.] [0]
# Antelope Canyon [0.] [0]
# Tunnes [0.8426396] [1]
# Sir Filip [0.] [0]
# Nerium [0.] [0]
# Hipop De Loire [0.] [0]
# Normfliegerin [0.00025672] [0]
# Ability [0.] [0]
# Earlofthecotswolds [0.] [0]
# Diamantis [0.] [0]
# Nacido [1.4189884e-13] [0]
# Sir Polski [0.] [0]
# Quebueno [0.] [0]
# Duca Di Como [0.7870673] [1]
# Plantstepsdream [0.] [0]
# Karibana [0.] [0]
# Ellis St Martin [0.] [0]
# Pusjkin [5.644523e-16] [0]
# Mystery Night [0.] [0]
# Beach Road One [2.895373e-23] [0]
# Hard One To Please [0.8401114] [1]
# Outbox [3.371864e-11] [0]
# Master Bloom [1.0553251e-10] [0]
# Quebello [5.8740787e-16] [0]
# Merlin's Beard [0.] [0]
# Espen Hill [0.04012617] [0]
# White Heart [0.] [0]
# Seneschal [0.00207648] [0]
# Timo Nurmos [0.00134971] [0]
# Jet Action [2.625157e-16] [0]
# Panjari [1.255347e-10] [0]
# Iron Butterfly [0.] [0]
# Auenfurst [0.] [0]
# Virginia Storm [0.] [0]
# Sublissimo [1.8912082e-20] [0]
# Could Be King [0.8000716] [1]
# Waldersee [0.] [0]
# Good Eye [0.] [0]
# Irish Action [0.00064909] [0]
# Brian Ryan [2.0728822e-07] [0]
# El Guanche [1.1214375e-25] [0]
# Tabdeed [0.] [0]
# Youonlyliveonce [0.] [0]
# City Code [4.4353406e-16] [0]
# Marshi [0.] [0]
# Faith In Humanity [0.6765781] [1]
# Gina Romantica [0.83518946] [0]
# Bahamian Club [1.9370797e-05] [0]
# Majestic Glory [1.6733435e-05] [0]
# A Mo Reay [4.505885e-19] [0]
# Miss Carol Ann [0.02785805] [0]
# Golden Rocket [4.3141808e-13] [0]
# Sail By [3.777887e-18] [0]
# Breeze Easy [5.5878754e-06] [0]
# Ready For The Lady [0.7569894] [1]
# British Royalty [0.00011154] [0]
# Collective Force [0.15107161] [0]
# King Vega [0.] [0]
# Elusive Knight [0.] [0]
# Enchant Me [0.] [0]
# Red Allure [0.77921724] [1]
# Burtonlodge Beauty [7.9383676e-17] [0]
# Birdie Bowers [0.00108688] [0]
# Eruption [0.00014773] [0]
# Basholo [1.02084044e-11] [0]
# Shesadabber [0.78864944] [0]
# Kraken Power [0.00029782] [0]
# Nodsasgoodasawink [0.0338171] [0]
# Tanasoq [0.00084792] [0]
# Captain Corcoran [0.] [0]
# Stroxx [0.7734356] [0]
# Zig Zag Zyggy [0.] [0]
# Sunset Glow [0.] [0]
# Lochnaver [0.72138286] [1]
# Simple Star [0.02223088] [0]
# Starlyte [0.] [0]
# Proton [0.] [0]
# Lucky Draw [0.00014653] [0]
# Cuban Cigar [0.] [0]
# Clan Jock [0.] [0]
# Ralphy Boy Two [0.] [0]
# Millie The Minx [0.] [0]
# A La Francaise [0.94144744] [1]
# Lechro [0.8110638] [0]
# Super Stars [0.] [0]
# Tafsir [0.] [0]
# Monroe Gold [0.01803796] [0]
# Sylvia Beach [0.] [0]
# Pasha Bay [0.5771052] [0]
# Kanzino [4.0978836e-27] [0]
# Salve Japan [0.] [0]
# Lady Hamilton [2.0533479e-10] [0]
# Zephlyn [0.] [0]
# Aghaboy [0.05233704] [1]
# The Insider [0.] [0]
# Surac [0.] [0]
# Arch Enemy [0.00365919] [0]
# Tory Reel [0.] [0]
# Common Practice [0.] [0]
# Pepsiwithacap [0.002882] [0]
# Bright Blue [2.1131187e-23] [0]
# Too Sharp [0.] [0]
# Circus Act [0.] [0]
# Papa Carlo [0.] [0]
# Easky Maid [2.7591626e-22] [0]
# Pont Audemer [0.] [0]
# Nikini [0.68144053] [1]
# Hollymount [0.] [0]
# Blanketontheground [4.5001432e-21] [0]
# Delante [0.] [0]
# Shannon Glory [0.] [0]
# Athagabhain [0.] [0]

# %%
wins = 0
fails = 0

moneyMade = 0
moneyLost = 0

for i in range(0, len(results)):
    if results[i] > 0.5:
        print(originalData[i][9], results[i], y_pred[i])
        if y_pred[i][0] == 0:
            fails += 1
            moneyLost += 1
        else:
            wins += 1
            moneyMade += float(originalData[i][15])
print(len(results), wins, fails, fails/wins)
print(moneyMade, moneyLost)
# Out:
# Installation [0.7225446] [1]
# Mordred [0.6908014] [1]
# Special Buddy [0.6865707] [1]
# See The Sea [0.8913501] [1]
# Iris Dancer [0.9459765] [1]
# Faith In Humanity [0.6765781] [1]
# Gina Romantica [0.83518946] [0]
# Duca Di Como [0.7870673] [1]
# Manitou [0.68999195] [1]
# Hard One To Please [0.8401114] [1]
# Could Be King [0.8000716] [1]
# Art House [0.8478547] [1]
# Saliera [0.72783077] [0]
# Tunnes [0.8426396] [1]
# California Vanes [0.8218739] [1]
# Winwin Thirtythree [0.5011295] [1]
# Quadruple Double [0.8451783] [1]
# Chiu Chow Brother [0.6060419] [1]
# President's Choice [0.77267665] [1]
# Baebae Tsoi [0.6769738] [1]
# Setanta [0.74230206] [1]
# Super Win Dragon [0.80826086] [1]
# Lucky With You [0.6950218] [1]
# Mr Ascendency [0.8438403] [1]
# The Gay Blade [0.72812635] [1]
# Miss Calculation [0.8591589] [0]
# Wiesentau [0.6674722] [1]
# Ready For The Lady [0.7569894] [1]
# Art House [0.8478547] [1]
# Saliera [0.72783077] [0]
# Wiesentau [0.6674722] [1]
# Tunnes [0.8426396] [1]
# Duca Di Como [0.7870673] [1]
# Hard One To Please [0.8401114] [1]
# Could Be King [0.8000716] [1]
# Faith In Humanity [0.6765781] [1]
# Gina Romantica [0.83518946] [0]
# Ready For The Lady [0.7569894] [1]
# Red Allure [0.77921724] [1]
# Shesadabber [0.78864944] [0]
# Stroxx [0.7734356] [0]
# Lochnaver [0.72138286] [1]
# A La Francaise [0.94144744] [1]
# Lechro [0.8110638] [0]
# Pasha Bay [0.5771052] [0]
# Nikini [0.68144053] [1]
# 464 37 9 0.24324324324324326
# 181.28500000000003 9
