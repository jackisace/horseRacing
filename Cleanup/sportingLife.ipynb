# %%
from bs4 import BeautifulSoup
import requests
from structure import *
import json

# %%
# GET HORSES INFO FROM RACE

def parseRace(url, raceInfo, numHorses):

    response = requests.get(url)
    soupthis = response.text
    soup = BeautifulSoup(soupthis, 'html.parser')

    horses = []
    jockeys = []
    trainers = []
    ages = []
    ors = []
    weights = []
    prices = []

    # OLD VARIABLES - NEED REMOVING
    topspeed = []
    countries = []
    firstWeights = []
    posLengths = []
    pedigrees = []
    positions = []
    startingPositions = []
    RPRs = []
    MRs = []
    forms = []

    horseNames = []
    odds = []
    info = []
    form = []

    i = 0

    runners = soup.find_all("div",{"data-test-id":"runner"})

    for runner in soup.find_all("div",{"data-test-id":"runner"}):

        i += 1

        try:
            horses.append(str(runner.find("a", id="horse-number-{}".format(i)).text).replace("\xa0", " "))
        except:
            horses.append(None)

        try:
            prices.append(runner.find("div", id="horse-odds-{}".format(i)).text)
        except:
            prices.append(None)



        item = runner.find("div",{"data-test-id":"horse-sub-info"})
        info = str(item.text) # Age: 2|  Weight: 9-2|  J: Daniel Muscutt|  T: C & M Johnston|  OR:  90|  D
        infos = info.split("|")
        try:
            ages.append(infos[0].split("Age: ")[1])
        except:
            ages.append(None)
        try:
            weights.append(infos[1].split("Weight: ")[1])
        except:
            weights.append(None)
        try:
            jockeys.append(str(infos[2].split("J: ")[1]).replace("Form:\xa0", ""))
        except:
            jockeys.append(None)
        try:
            trainers.append(str(infos[3].split("T: ")[1]).replace("Form:\xa0", ""))
        except:
            trainers.append(None)
        try:
            ors.append(infos[4].split("OR:  ")[1])
        except:
            ors.append(None)
        topspeed.append(None)
        countries.append(None)
        firstWeights.append(None)
        posLengths.append(None)
        pedigrees.append(None)
        positions.append(None)
        startingPositions.append(None)
        RPRs.append(None)
        MRs.append(None)



        item = runner.find("div",{"data-test-id":"show-form"})
        try:
            forms.append(str(item.text).replace("Form:\xa0", ""))
        except:
            forms.append(None)


    


    currentRace = race(raceInfo, url)
    for i in range(0,numHorses):
        thisHorse = horse(  horses[i], 
                            jockeys[i], 
                            trainers[i], 
                            ages[i], 
                            topspeed[i], 
                            weights[i], 
                            ors[i], 
                            prices[i], 
                            countries[i], 
                            firstWeights[i], 
                            posLengths[i],
                            pedigrees[i],
                            positions[i],
                            startingPositions[i],
                            RPRs[i],
                            MRs[i],
                            forms[i])
    currentRace.saveSL()
    #currentRace.print()


# GET TOMORROWS RACE URLS

url = "https://www.sportinglife.com/racing/racecards/tomorrow"
response = requests.get(url)
soupthis = response.text
soup = BeautifulSoup(soupthis, 'html.parser')

a = str(soupthis.split('application/json">')[1])
a = a.split('</script>')[0]
parsed = json.loads(a)

url = "https://www.sportinglife.com/racing/racecards/DATE/PLACE/racecard/RACEID/NAME"
urls = []
for item in parsed["props"]["pageProps"]["meetings"]:
    for Race in item["races"]:
        numHorses = int(Race["ride_count"])
        time = str(Race["time"])
        date =  str(Race["date"])
        age = str(Race["age"])
        race_class = str(Race["race_class"])
        distance = str(Race["distance"])
        raceId = str(Race["race_summary_reference"]["id"])
        raceName = str(Race["name"])
        racePlace = str(Race["course_name"])
        URL = url.replace("DATE", date)
        URL = URL.replace("PLACE", racePlace)
        URL = URL.replace("RACEID", raceId)
        URL = URL.replace("NAME", raceName)
        URL = URL.replace(" ", "-").replace("(", "").replace(")", "").replace("'", "").replace('"','')
        urls.append(URL)
        #print(json.dumps(Race, indent=4))
        #print()

        raceInfo = []
        raceInfo.append(date)
        raceInfo.append(time)
        raceInfo.append(racePlace)
        raceInfo.append(raceName)
        raceInfo.append(race_class)
        raceInfo.append(age)
        raceInfo.append(distance)
        raceInfo.append(None)
        raceInfo.append(None)

        parseRace(URL, raceInfo, numHorses)
        #input("DONE")


        
#print(urls)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jack/horseRacing/sportingLife.ipynb Cell 2 in 1
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=162'>163</a> raceInfo.append(None)
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=163'>164</a> raceInfo.append(None)
# --> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=165'>166</a> parseRace(URL, raceInfo, numHorses)
#
# /home/jack/horseRacing/sportingLife.ipynb Cell 2 in 1
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=98'>99</a> currentRace = race(raceInfo, url)
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=99'>100</a> for i in range(0,numHorses):
# --> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=100'>101</a>     thisHorse = horse(  horses[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=101'>102</a>                         jockeys[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=102'>103</a>                         trainers[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=103'>104</a>                         ages[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=104'>105</a>                         topspeed[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=105'>106</a>                         weights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=106'>107</a>                         ors[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=107'>108</a>                         prices[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=108'>109</a>                         countries[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=109'>110</a>                         firstWeights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=110'>111</a>                         posLengths[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=111'>112</a>                         pedigrees[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=112'>113</a>                         positions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=113'>114</a>                         startingPositions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=114'>115</a>                         RPRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=115'>116</a>                         MRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=116'>117</a>                         forms[i])
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W1sZmlsZQ%3D%3D?line=117'>118</a> currentRace.saveSL()
#
# IndexError: list index out of range

# %%
from argparse import _MutuallyExclusiveGroup
from bs4 import BeautifulSoup
import requests
import re
from structure import *
from raceParser import *
import datetime
import random
import time
datetime_object = datetime.datetime.now()

url = "https://www.sportinglife.com/racing/results/DATE"

URLs = []
numberOfDaysToMilk = 6200

for i in range(numberOfDaysToMilk): # 6200
    datetime_object = datetime_object - datetime.timedelta(days=1)
    date = (str(datetime_object).split(" ")[0])
    URLs.append(url.replace("DATE", date))


for URL in URLs: # FOR EACH DATE
    print(URL)
    raceURLs = []
    urlhtml = requests.get(URL)
    soupthisDate = urlhtml.text
    dateSoup = BeautifulSoup(soupthisDate, 'html.parser')

    #data-test-id="race-container"
    for item in dateSoup.find_all('div', {'data-test-id':"race-container"}): # FOR EACH RACE
        page = str(item).split('href="')[1]
        page = page.split('">')[0]
        raceURLs.append(str("https://www.sportinglife.com" + page))

    






    a = str(soupthisDate.split('application/json">')[1])
    a = a.split('</script>')[0]
    parsed = json.loads(a)

    url = "https://www.sportinglife.com/racing/racecards/DATE/PLACE/racecard/RACEID/NAME"
    urls = []
    for item in parsed["props"]["pageProps"]["meetings"]:
        for Race in item["races"]:
            numHorses = int(Race["ride_count"])
            time = str(Race["time"])
            date =  str(Race["date"])
            age = str(Race["age"])
            race_class = str(Race["race_class"])
            distance = str(Race["distance"])
            raceId = str(Race["race_summary_reference"]["id"])
            raceName = str(Race["name"])
            racePlace = str(Race["course_name"])
            URL = url.replace("DATE", date)
            URL = URL.replace("PLACE", racePlace)
            URL = URL.replace("RACEID", raceId)
            URL = URL.replace("NAME", raceName)
            URL = URL.replace(" ", "-").replace("(", "").replace(")", "").replace("'", "").replace('"','')
            urls.append(URL)
            #print(json.dumps(Race, indent=4))
            #print()

            raceInfo = []
            raceInfo.append(date)
            raceInfo.append(time)
            raceInfo.append(racePlace)
            raceInfo.append(raceName)
            raceInfo.append(race_class)
            raceInfo.append(age)
            raceInfo.append(distance)
            raceInfo.append(None)
            raceInfo.append(None)

            parseRace(URL, raceInfo, numHorses)
# Out:
# https://www.sportinglife.com/racing/results/2023-05-01
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jack/horseRacing/sportingLife.ipynb Cell 3 in 8
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=76'>77</a> raceInfo.append(None)
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=77'>78</a> raceInfo.append(None)
# ---> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=79'>80</a> parseRace(URL, raceInfo, numHorses)
#
# /home/jack/horseRacing/sportingLife.ipynb Cell 3 in 9
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=96'>97</a> currentRace = race(raceInfo, url)
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=97'>98</a> for i in range(0,numHorses):
# ---> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=98'>99</a>     thisHorse = horse(  horses[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=99'>100</a>                         jockeys[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=100'>101</a>                         trainers[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=101'>102</a>                         ages[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=102'>103</a>                         topspeed[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=103'>104</a>                         weights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=104'>105</a>                         ors[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=105'>106</a>                         prices[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=106'>107</a>                         countries[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=107'>108</a>                         firstWeights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=108'>109</a>                         posLengths[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=109'>110</a>                         pedigrees[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=110'>111</a>                         positions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=111'>112</a>                         startingPositions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=112'>113</a>                         RPRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=113'>114</a>                         MRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=114'>115</a>                         forms[i])
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W2sZmlsZQ%3D%3D?line=115'>116</a> currentRace.saveSL()
#
# IndexError: list index out of range

# %%
# BACKWARDS REACHING DATA

url = "https://www.sportinglife.com/racing/results/2022-09-22"


response = requests.get(url)
soupthis = response.text
soup = BeautifulSoup(soupthis, 'html.parser')

a = str(soupthis.split('application/json">')[1])
a = a.split('</script>')[0]
parsed = json.loads(a)


urls = []
for item in parsed["props"]["pageProps"]["meetings"]:
    for Race in item["races"]:
        numHorses = int(Race["ride_count"])
        time = str(Race["time"])
        date =  str(Race["date"])
        age = str(Race["age"])
        race_class = str(Race["race_class"])
        distance = str(Race["distance"])
        raceId = str(Race["race_summary_reference"]["id"])
        raceName = str(Race["name"])
        racePlace = str(Race["course_name"])
        URL = "https://www.sportinglife.com/racing/racecards/DATE/PLACE/racecard/RACEID/NAME"
        URL = URL.replace("DATE", date)
        URL = URL.replace("PLACE", racePlace)
        URL = URL.replace("RACEID", raceId)
        URL = URL.replace("NAME", raceName)
        URL = URL.replace(" ", "-").replace("(", "").replace(")", "").replace("'", "").replace('"','')
        urls.append(URL)
        #print(json.dumps(Race, indent=4))
        #print()

        raceInfo = []
        raceInfo.append(date)
        raceInfo.append(time)
        raceInfo.append(racePlace)
        raceInfo.append(raceName)
        raceInfo.append(race_class)
        raceInfo.append(age)
        raceInfo.append(distance)
        raceInfo.append(None)
        raceInfo.append(None)

        parseRace(URL, raceInfo, numHorses)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jack/horseRacing/sportingLife.ipynb Cell 4 in 4
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=44'>45</a> raceInfo.append(None)
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=45'>46</a> raceInfo.append(None)
# ---> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=47'>48</a> parseRace(URL, raceInfo, numHorses)
#
# /home/jack/horseRacing/sportingLife.ipynb Cell 4 in 1
#      <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=98'>99</a> currentRace = race(raceInfo, url)
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=99'>100</a> for i in range(0,numHorses):
# --> <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=100'>101</a>     thisHorse = horse(  horses[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=101'>102</a>                         jockeys[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=102'>103</a>                         trainers[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=103'>104</a>                         ages[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=104'>105</a>                         topspeed[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=105'>106</a>                         weights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=106'>107</a>                         ors[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=107'>108</a>                         prices[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=108'>109</a>                         countries[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=109'>110</a>                         firstWeights[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=110'>111</a>                         posLengths[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=111'>112</a>                         pedigrees[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=112'>113</a>                         positions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=113'>114</a>                         startingPositions[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=114'>115</a>                         RPRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=115'>116</a>                         MRs[i],
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=116'>117</a>                         forms[i])
#     <a href='vscode-notebook-cell:/home/jack/horseRacing/sportingLife.ipynb#W3sZmlsZQ%3D%3D?line=117'>118</a> currentRace.saveSL()
#
# IndexError: list index out of range
